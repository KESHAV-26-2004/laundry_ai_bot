# %%
#pip install --upgrade jupyter ipywidgets
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#!pip install torch transformers datasets tokenizers numpy

# %%
#!pip install sentencepiece

# %%
#pip install hf_xet
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
import random

# Base FAQ entries with a "base" question and its answer.
base_faqs = [
    {"base": "How do I place an order?", "answer": "Go to 'New Order' and select your laundry items."},
    {"base": "How do I check my order history?", "answer": "You can check your order history under the 'Order History' section."},
    {"base": "What payment options are available?", "answer": "We accept UPI, credit/debit cards, and cash on delivery."},
    {"base": "How long does laundry take?", "answer": "Laundry typically takes 24-48 hours depending on the load."},
    {"base": "How do I request dry cleaning?", "answer": "Select 'Dry Cleaning' while placing your order."},
    {"base": "What are the prices for laundry services?", "answer": "Prices vary by item type; please refer to the 'Price List'."},
    {"base": "How do I cancel an order?", "answer": "Go to 'Order History' and click on 'Cancel Order'."},
    {"base": "How can I leave feedback?", "answer": "Use the 'Help & Feedback' section in the app to leave your comments."},
    {"base": "How do I remove tough stains?", "answer": "Pre-treat the stain with a stain remover before washing."},
    {"base": "How can I prevent color bleeding?", "answer": "It's best to wash colored clothes separately from whites."},
    {"base": "What happens if my order is delayed?", "answer": "Delays may occur due to high demand; check the app for updates or contact support."},
    {"base": "How do I know when my laundry is done?", "answer": "You will receive a notification in the app once your order is complete."},
    {"base": "How do I pay for my laundry order?", "answer": "Payments can be made via UPI, card, or cash on delivery."},
    {"base": "What should I do if I receive the wrong order?", "answer": "Report the issue through the app immediately so we can resolve it."},
    {"base": "Can I request express laundry service?", "answer": "Yes, select 'Express Delivery' during order placement for a faster turnaround."},
    {"base": "How do I schedule a laundry pickup?", "answer": "Choose your preferred pickup time when placing your order."},
    {"base": "How should I wash woolen clothes?", "answer": "Hand wash in cold water or use a wool cycle on your machine."},
    {"base": "What is the best way to clean delicate fabrics?", "answer": "Use a gentle cycle with mild detergent to protect delicate fabrics."},
    {"base": "How do I remove ink stains?", "answer": "Blot the stain with rubbing alcohol before washing."},
    {"base": "How can I get my laundry done quickly if I'm in a rush?", "answer": "Opt for our express service option for a quicker turnaround."},
    {"base": "Which detergent should I use?", "answer": "Use a detergent suitable for your fabric type, as indicated on the care label."},
    {"base": "How do I maintain my washing machine?", "answer": "Run a cleaning cycle with vinegar or a specialized cleaner periodically."},
    {"base": "How do I request a refund?", "answer": "If you are unsatisfied, contact support through the app to request a refund."},
    {"base": "What should I do if my clothes are damaged?", "answer": "Report any damaged items via the support section, and we'll address the issue."},
    {"base": "How do I track my laundry order?", "answer": "Check the order status in the 'Order History' section."},
    {"base": "How do I update my payment method?", "answer": "Update your payment details in the 'Account Settings' section."},
    {"base": "What happens if my laundry order is missed?", "answer": "You will receive a reminder, and you can reschedule the pickup."},
    {"base": "Can I schedule orders in advance?", "answer": "Yes, you can choose a future pickup time when placing an order."},
    {"base": "How do I choose the correct service for my clothes?", "answer": "Refer to the service guide in the app for recommendations."},
    {"base": "How do I know if my detergent is eco-friendly?", "answer": "Eco-friendly detergents are marked in the 'Price List' section."},
    {"base": "What if I need to change my pickup address?", "answer": "Update your address in the 'Account Settings' before placing an order."},
    {"base": "How do I request ironing services?", "answer": "Add ironing as an option when placing your order."},
    {"base": "How do I wash sportswear effectively?", "answer": "Wash sportswear in cold water and avoid fabric softeners."},
    {"base": "How do I remove stubborn grease stains?", "answer": "Pre-treat grease stains with dish soap before washing."},
    {"base": "What precautions should I take for heavily soiled clothes?", "answer": "Pre-soak and use a heavy-duty cycle for heavily soiled garments."},
    {"base": "How do I maintain the color of my red clothes?", "answer": "Wash red clothes separately using cold water and a mild detergent."},
    {"base": "What is the recommended cycle for washing silk?", "answer": "Use a delicate cycle with cold water and a detergent designed for silk."},
    {"base": "How do I care for my leather jacket?", "answer": "Wipe it with a damp cloth and use a leather conditioner; do not machine wash."},
    {"base": "How do I remove water stains from clothes?", "answer": "Pre-treat with a vinegar solution before washing."},
    {"base": "How can I reduce wrinkles when drying clothes?", "answer": "Remove clothes promptly from the dryer and use a wrinkle-release spray."},
    {"base": "How do I clean my laundry basket?", "answer": "Wash it with mild detergent and warm water on a regular basis."},
    {"base": "How do I wash heavily embroidered clothes?", "answer": "Hand wash gently to avoid damaging the embroidery."},
    {"base": "How can I brighten dull clothes?", "answer": "Add a booster like baking soda or vinegar to your wash cycle."},
    {"base": "What detergent should I use for baby clothes?", "answer": "Use a hypoallergenic detergent specially formulated for babies."},
    {"base": "How do I remove stubborn blood stains?", "answer": "Rinse immediately with cold water and then pre-treat with a stain remover."},
    {"base": "What should I do if I ask something the AI is not trained on?", "answer": "The AI will provide a general response and suggest contacting support for more details."},
    {"base": "Tell me a laundry joke.", "answer": "Why did the shirt go to school? It wanted to get ironed out!"}
]

# Function to create multiple variations for each base question
def create_variations(base_question, answer):
    templates = [
        f"{base_question}",
        f"Can you tell me {base_question.lower()}?",
        f"I want to know {base_question.lower()}",
        f"How exactly do I {base_question.lower()}?",
        f"Please explain {base_question.lower()}",
        f"What are the steps to {base_question.lower()}?",
        f"Guide me on {base_question.lower()}",
        f"Could you explain how to {base_question.lower()}?",
        f"I need help with {base_question.lower()}",
        f"What's the process to {base_question.lower()}?"
    ]
    return [{"question": t, "answer": answer} for t in templates]

# Generate variations from the base FAQs
all_entries = []
for faq in base_faqs:
    variations = create_variations(faq["base"], faq["answer"])
    all_entries.extend(variations)

# If the total entries are less than 500, duplicate and shuffle until we reach 500 entries
while len(all_entries) < 500:
    all_entries.append(random.choice(all_entries))

# Optionally, shuffle the dataset so that the order is randomized
random.shuffle(all_entries)

# Save the complete dataset to a JSON file
with open('laundry_dataset.json', 'w') as f:
    json.dump(all_entries, f, indent=2)

print(f"Dataset generated with {len(all_entries)} entries and saved to 'laundry_dataset.json'.")
# Out:
# Dataset generated with 500 entries and saved to 'laundry_dataset.json'.

# %%
import json

# Load the dataset
with open('laundry_dataset.json', 'r') as file:
    data = json.load(file)

# Display the first few entries to check the format
for i, entry in enumerate(data[:20]):  # Change the range to display more entries
    print(f"Question {i + 1}: {entry['question']}")
    print(f"Answer: {entry['answer']}")
    print('-' * 50)
# Out:
# Question 1: Can you tell me how do i maintain the color of my red clothes??
# Answer: Wash red clothes separately using cold water and a mild detergent.
# --------------------------------------------------
# Question 2: What are the steps to which detergent should i use??
# Answer: Use a detergent suitable for your fabric type, as indicated on the care label.
# --------------------------------------------------
# Question 3: Could you explain how to how do i remove tough stains??
# Answer: Pre-treat the stain with a stain remover before washing.
# --------------------------------------------------
# Question 4: I want to know how do i place an order?
# Answer: Go to 'New Order' and select your laundry items.
# --------------------------------------------------
# Question 5: What's the process to how long does laundry take??
# Answer: Laundry typically takes 24-48 hours depending on the load.
# --------------------------------------------------
# ...
